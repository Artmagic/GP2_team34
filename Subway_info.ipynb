# %% [markdown]
# <a href="https://colab.research.google.com/github/Artmagic/GP2_team34/blob/main/Subway_info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
query = """
[out:json][timeout:90];
area["name"="Москва"]->.searchArea;
(
  node["railway"="station"]["station"="subway"](area.searchArea);
  node["railway"="subway_entrance"](area.searchArea);
);
out body;
"""

url = "https://overpass.kumi.systems/api/interpreter"
print("Запрос Overpass API")
response = requests.get(url, params={"data": query}, timeout=120)
response.raise_for_status()
data = response.json()

stations = []
for el in data["elements"]:
    name = el["tags"].get("name")
    lat = el.get("lat")
    lon = el.get("lon")
    if name and lat and lon:
        stations.append({"name": name, "lat": lat, "lon": lon})

df_metro = pd.DataFrame(stations)
print(f"Станций найдено: {len(df_metro)}")

df_metro.to_csv("moscow_metro.csv", index=False, encoding="utf-8-sig")
print("💾 Сохранено в moscow_metro.csv")

df_metro.head(100)
# Out:
# Запрос Overpass API
# Станций найдено: 272
# 💾 Сохранено в moscow_metro.csv
#               name        lat        lon
# 0       Медведково  55.887177  37.661550
# 1     Бабушкинская  55.869634  37.664110
# 2     Партизанская  55.788503  37.750993
# 3      Семёновская  55.783307  37.721282
# 4   Филёвский парк  55.739508  37.483372
# ..             ...        ...        ...
# 95     Кожуховская  55.707586  37.684618
# 96       Печатники  55.693491  37.726952
# 97        Волжская  55.690826  37.753101
# 98         Люблино  55.675721  37.761958
# 99         Марьино  55.650016  37.743147
#
# [100 rows x 3 columns]
